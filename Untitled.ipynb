# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("gg2.csv")

# %%
df.head(5)
# Out:
#   DATE (YYYY-MM-DDTHH:MI:SSZ)  LATITUDE (degree_north)  \
# 0        2024-05-03T08:45:40Z                   13.511
# 1        2024-05-03T08:45:40Z                   13.511
# 2        2024-05-03T08:45:40Z                   13.511
# 3        2024-05-03T08:45:40Z                   13.511
# 4        2024-05-03T08:45:40Z                   13.511
#
#    LONGITUDE (degree_east)  DEPH (meter)  DOXY (millimole/m3)  PRES (decibar)  \
# 0                   88.512          10.0              141.177              10
# 1                   88.512          10.0              190.646              15
# 2                   88.512          10.0              189.598              20
# 3                   88.512          10.0              194.023              25
# 4                   88.512          10.0              198.631              30
#
#    PSAL (psu)  TEMP (degree_Celsius)
# 0     31.8862                31.1199
# 1     32.4680                31.1330
# 2     32.4831                31.1234
# ...

# %%
df.isnull().sum()
# Out:
# DATE (YYYY-MM-DDTHH:MI:SSZ)    0
# LATITUDE (degree_north)        0
# LONGITUDE (degree_east)        0
# DEPH (meter)                   0
# DOXY (millimole/m3)            0
# PRES (decibar)                 0
# PSAL (psu)                     0
# TEMP (degree_Celsius)          0
# dtype: int64

# %%
mn=df["PSAL (psu)"].mean()

# %%
mn
# Out:
# 34.818178606965176

# %%
md=df["PSAL (psu)"].mode()

# %%
md
# Out:
# 0    35.0465
# Name: PSAL (psu), dtype: float64

# %%
me=df["PSAL (psu)"].median()

# %%
me
# Out:
# 34.829

# %%
plt.figure(figsize=(10,5))
sns.histplot(x="PSAL (psu)",data=df,bins=[i for i in range(30,40,1)])
plt.plot([mn for i in range(0,600)],[i for i in range(0,600)],c="green",label="Mean")
plt.plot([md for i in range(0,600)],[i for i in range(0,600)],c="red",label="Mode")
plt.plot([me for i in range(0,600)],[i for i in range(0,600)],c="black",label="Median")
plt.legend()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603 entries, 0 to 602
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   DATE (YYYY-MM-DDTHH:MI:SSZ)  603 non-null    object
#  1   LATITUDE (degree_north)      603 non-null    float64
#  2   LONGITUDE (degree_east)      603 non-null    float64
#  3   DEPH (meter)                 603 non-null    float64
#  4   DOXY (millimole/m3)          603 non-null    float64
#  5   PRES (decibar)               603 non-null    int64
#  6   PSAL (psu)                   603 non-null    float64
#  7   TEMP (degree_Celsius)        603 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 37.8+ KB

# %%
dmn=df["DOXY (millimole/m3)"].mean()
dmd=df["DOXY (millimole/m3)"].mode()[0]
dme=df["DOXY (millimole/m3)"].median()
dmn,dmd,dme
# Out:
# (75.38803814262022, 1.944, 82.226)

# %%
plt.figure(figsize=(10,5))
sns.histplot(x="DOXY (millimole/m3)",data=df,bins=[i for i in range(1,210,1)],kde=True)
plt.plot([dmn for i in range(0,50)],[i for i in range(0,50)],c="green",label="Mean")
plt.plot([dmd for i in range(0,50)],[i for i in range(0,50)],c="red",label="Mode")
plt.plot([dme for i in range(0,50)],[i for i in range(0,50)],c="black",label="Median")
plt.legend()
plt.show()

# %%
tmn=df["TEMP (degree_Celsius)"].mean()
tmd=df["TEMP (degree_Celsius)"].mode()[0]
tme=df["TEMP (degree_Celsius)"].median()
tmn,tmd,tme
plt.figure(figsize=(10,5))
sns.histplot(x="TEMP (degree_Celsius)",data=df,bins=[i for i in range(0,32,1)],kde=True)
plt.plot([tmn for i in range(0,140)],[i for i in range(0,140)],c="green",label="Mean")
plt.plot([tmd for i in range(0,140)],[i for i in range(0,140)],c="red",label="Mode")
plt.plot([tme for i in range(0,140)],[i for i in range(0,1)],c="black",label="Median")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 9
#       7 plt.plot([tmn for i in range(0,140)],[i for i in range(0,140)],c="green",label="Mean")
#       8 plt.plot([tmd for i in range(0,140)],[i for i in range(0,140)],c="red",label="Mode")
# ----> 9 plt.plot([tme for i in range(0,140)],[i for i in range(0,1)],c="black",label="Median")
#      10 plt.legend()
#      11 plt.show()
#
# File h:\py\Lib\site-packages\matplotlib\pyplot.py:3794, in plot(scalex, scaley, data, *args, **kwargs)
#    3786 @_copy_docstring_and_deprecators(Axes.plot)
#    3787 def plot(
#    3788     *args: float | ArrayLike | str,
#    (...)
#    3792     **kwargs,
#    3793 ) -> list[Line2D]:
# -> 3794     return gca().plot(
#    3795         *args,
#    3796         scalex=scalex,
#    3797         scaley=scaley,
#    3798         **({"data": data} if data is not None else {}),
# ...

# %%
sns.histplot(x="TEMP (degree_Celsius)",data=df,bins=[i for i in range(0,32,1)],kde=True)
# Out:
# <Axes: xlabel='TEMP (degree_Celsius)', ylabel='Count'>

# %%
pmn=df["PRES (decibar)"].mean()
pmd=df["PRES (decibar)"].mode()[0]
pme=df["PRES (decibar)"].median()
plt.figure(figsize=(10,5))
sns.histplot(data=df,x="PRES (decibar)",bins=[i for i in range(10,3200,100)])
plt.plot([pmn for i in range(0,50)],[i for i in range(0,50)],c="green",label="Mean")
plt.plot([pmd for i in range(0,50)],[i for i in range(0,50)],c="red",label="Mode")
plt.plot([pme for i in range(0,50)],[i for i in range(0,50)],c="black",label="Median")
plt.legend()
plt.show()

# %%
pmn,pmd,pme
# Out:
# (1515.0, 10, 1515.0)

# %%
sns.histplot(x="DOXY (millimole/m3)",data=df,bins=[i for i in range(0,220,10)],kde=True)
# Out:
# <Axes: xlabel='DOXY (millimole/m3)', ylabel='Count'>

# %%
sns.histplot(x="PSAL (psu)",data=df,bins=[i for i in range(30,40,1)], kde=True)
# Out:
# <Axes: xlabel='PSAL (psu)', ylabel='Count'>

# %%
co_mtx = df.corr(numeric_only=True)
co_mtx
plt.figure(figsize=(10,5))
sns.heatmap(co_mtx, cmap="magma", annot=True)

# Display heatmap
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603 entries, 0 to 602
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   DATE (YYYY-MM-DDTHH:MI:SSZ)  603 non-null    object
#  1   LATITUDE (degree_north)      603 non-null    float64
#  2   LONGITUDE (degree_east)      603 non-null    float64
#  3   DEPH (meter)                 603 non-null    float64
#  4   DOXY (millimole/m3)          603 non-null    float64
#  5   PRES (decibar)               603 non-null    int64
#  6   PSAL (psu)                   603 non-null    float64
#  7   TEMP (degree_Celsius)        603 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 37.8+ KB

# %%
sxy=df['PSAL (psu)'].to_numpy().reshape((-1,1))
txy=df['TEMP (degree_Celsius)'].to_numpy().reshape((-1,1))
pxy=df['PRES (decibar)'].to_numpy().reshape((-1,1))
doxy=df['DOXY (millimole/m3)'].to_numpy().reshape((-1,1))
dxy=df['DEPH (meter)'].to_numpy().reshape((-1,1))

# %%
plt.scatter(pxy,doxy)

# %%
>>> import numpy as np
>>> from sklearn.linear_model import LinearRegression

# %%
>>> model = LinearRegression().fit(pxy, doxy)
>>> r_sq = model.score(pxy,doxy)
>>> print(f"coefficient of determination: {r_sq}")
print(f"intercept: {model.intercept_}")
print(f"slope: {model.coef_}")
# Out:
# coefficient of determination: 0.6533857518843083
# intercept: [4.21485517]
# slope: [[0.046979]]

# %%
plt.scatter(dxy,txy)

# %%
>>> model = LinearRegression().fit(dxy, txy)
>>> r_sq = model.score(dxy,txy)
>>> print(f"coefficient of determination: {r_sq}")
print(f"intercept: {model.intercept_}")
print(f"slope: {model.coef_}")
# Out:
# coefficient of determination: 0.6641267291758937
# intercept: [13.8265944]
# slope: [[-0.00467927]]

# %%
plt.scatter(pxy,txy)

# %%
>>> model = LinearRegression().fit(pxy, txy)
>>> r_sq = model.score(pxy,txy)
>>> print(f"coefficient of determination: {r_sq}")
print(f"intercept: {model.intercept_}")
print(f"slope: {model.coef_}")
# Out:
# coefficient of determination: 0.6639811510916931
# intercept: [13.93228482]
# slope: [[-0.00516501]]

# %%
plt.scatter(dxy,doxy)

# %%
>>> model = LinearRegression().fit(dxy, doxy)
>>> r_sq = model.score(dxy,doxy)
>>> print(f"coefficient of determination: {r_sq}")
print(f"intercept: {model.intercept_}")
print(f"slope: {model.coef_}")
# Out:
# coefficient of determination: 0.6520124026634122
# intercept: [5.25769164]
# slope: [[0.04251147]]

# %%
df.describe()
# Out:
#        LATITUDE (degree_north)  LONGITUDE (degree_east)  DEPH (meter)  \
# count             6.030000e+02             6.030000e+02    603.000000
# mean              1.351100e+01             8.851200e+01   1649.680697
# std               1.973393e-13             6.542420e-13    961.606231
# min               1.351100e+01             8.851200e+01     10.000000
# 25%               1.351100e+01             8.851200e+01    818.981858
# 50%               1.351100e+01             8.851200e+01   1649.680697
# 75%               1.351100e+01             8.851200e+01   2480.379536
# max               1.351100e+01             8.851200e+01   3311.078374
#
#        DOXY (millimole/m3)  PRES (decibar)  PSAL (psu)  TEMP (degree_Celsius)
# count           603.000000       603.00000  603.000000             603.000000
# mean             75.388038      1515.00000   34.818179               6.107298
# std              50.626212       871.07692    0.323488               5.521405
# ...
